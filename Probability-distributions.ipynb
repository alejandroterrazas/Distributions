# %%
#%matplotlib inline
#import matplotlib.pyplot as plt

import seaborn as sns
# settings for seaborn plotting style
sns.set()
sns.set(color_codes=True)
current_palette = sns.color_palette("muted", n_colors=5)

# settings for seaborn plot sizes
sns.set(rc={'figure.figsize':(4.5,3)})

import numpy as np
from scipy.stats import uniform

sns.set_style("dark")

#sns.set_style("darkgrid", {"axes.facecolor": ".9"})

# %% [markdown]
# ## 1. Uniform Distribution
#
# One of the most foundational statistical distributions is the *uniform distribution*, where any interval of numbers of equal width has an equal probability of being observed. The uniform distribution resembles a rectangle, with constant height across the interval and 0 height elsewhere. As with all statistical distributions, the area under the curve must be equal to 1.
# The following figure shows a uniform distribution in interval (a,b). The height is set to 1/(b−a)
# .

# %%
# random numbers from uniform distribution
# Generate 10 numbers from 0 to 10
n = 10000
a = 0
b = 10
data_uniform = uniform.rvs(size=n, loc = a, scale=b)  

ax = sns.distplot(data_uniform,
                  bins=100,
                  kde=False,
                  color='red')
ax.set(xlabel='Uniform ', ylabel='Frequency')
# Out:
# [Text(0, 0.5, 'Frequency'), Text(0.5, 0, 'Uniform ')]

# %% [markdown]
# ## 2. The normal distribution.
#
# The normal distribution (aka the Guassian distribution) is the most well-known distribution in statistics.  Many data science methods assume the normal distribution.
#
# A normal distribution has a symetric, bell-shaped density curve described by two parameters, the mean μ and the standard deviation σ.  The density is centered about its mean, with its spread determined by its standard deviation.
#
# Approximately 68% of the data falls within one standard deviation from the mean on either side and 95% within two standard deviations. Also it worth mentioning that a distribution with mean 0 and standard deviation 1 is called a *standard normal distribution*.

# %%
from scipy.stats import norm
# generate random numbersfrom N(0,1)
data_normal = norm.rvs(size=10000,loc=0,scale=1)

ax = sns.distplot(data_normal,
                  bins=100,
                  kde=False,
                  color='blue')
ax.set(xlabel='Normal', ylabel='Frequency')
# Out:
# [Text(0, 0.5, 'Frequency'), Text(0.5, 0, 'Normal')]

# %% [markdown]
# ## 3. Gamma Distribution
#
# The gamma distribution is a two-parameter family of continuous probability distributions. Several commonly used distributions including the exponential, chi-squared, and erlang distributions are special cases of the gamma distribution. The gamma distribution can be parameterized in terms of a shape parameter α=k and an inverse scale parameter β=1/θ, called a rate parameter., the symbol Γ(n) is the gamma function and is defined as (n−1)!

# %%
from scipy.stats import gamma
data_gamma = gamma.rvs(a=5, size=10000)

ax = sns.distplot(data_gamma,
                  kde=True,
                  bins=100,
                  color='blue')
ax.set(xlabel='Gamma Distribution', ylabel='Frequency')
# Out:
# [Text(0, 0.5, 'Frequency'), Text(0.5, 0, 'Gamma Distribution')]

# %% [markdown]
# ## 4. Exponential Distribution
#
# The exponential distribution describes the time between events in a Poisson point process--a process in which events occur *continuously and independently* at a constant average rate. The distribution is described by a parameter λ called the rate parameter.

# %%
from scipy.stats import expon
data_expon = expon.rvs(scale=1,loc=0,size=1000)

ax = sns.distplot(data_expon,
                  kde=True,
                  bins=100,
                  color='blue')
ax.set(xlabel='Exponential Distribution', ylabel='Frequency')
# Out:
# [Text(0, 0.5, 'Frequency'), Text(0.5, 0, 'Exponential Distribution')]

# %% [markdown]
# ## 5. Poisson Distribution
#
# A Poisson random variable is typically used to model the number of times an event happens in a time interval. For example, the number of open tellers at the bank in a five minute interval can be thought of a Poisson process. The distribution is described in terms of the rate (μ) at which the events happen. An event can occur 0, 1, 2, … times in an interval. The average number of events in an interval (the rate parameter) is designated λ (lambda).

# %%
from scipy.stats import poisson
data_poisson = poisson.rvs(mu=3, size=10000)

ax = sns.distplot(data_poisson,
                  bins=30,
                  kde=False,
                  color='blue')
ax.set(xlabel='Poisson Distribution', ylabel='Frequency')
# Out:
# [Text(0, 0.5, 'Frequency'), Text(0.5, 0, 'Poisson Distribution')]

# %% [markdown]
# ## 6. Binomial Distribution
#
# The binomial distribution describes the probability where only two outcomes are possible, such as success or failure, gain or loss, win or lose and where the probability of success and failure is same for all the trials is called a Binomial Distribution. However, The outcomes need not be equally likely, and each trial is independent of each other. The parameters of a binomial distribution are n and p, where n is the total number of trials, and p is the probability of success in each trial.

# %%
from scipy.stats import binom
data_binom = binom.rvs(n=10,p=0.8,size=10000)

ax = sns.distplot(data_binom,
                  kde=False,
                  color='blue')
ax.set(xlabel='Binomial Distribution', ylabel='Frequency')
# Out:
# [Text(0, 0.5, 'Frequency'), Text(0.5, 0, 'Binomial Distribution')]

# %% [markdown]
# ## 7. Bernoulli Distribution
#
# A Bernoulli distribution has only two possible outcomes, namely 1 (success) and 0 (failure), and a single trial, for example, a coin toss. So the random variable X which has a Bernoulli distribution can take value 1
# with the probability of success, p, and the value 0 with the probability of failure, q or 1−p. The probabilities of success and failure need not be equally likely. The Bernoulli distribution is a special case of the binomial distribution where a single trial is conducted (n=1).

# %%
# import bernoulli
from scipy.stats import bernoulli

# generate bernoulli
data_bern = bernoulli.rvs(size=10000,p=0.3)
ax= sns.distplot(data_bern,
                 kde=False,
                 color="skyblue")
ax.set(xlabel='Bernoulli', ylabel='Frequency')
# Out:
# [Text(0, 0.5, 'Frequency'), Text(0.5, 0, 'Bernoulli')]

# %%
from scipy.stats import poisson
data_poisson = poisson.rvs(mu=3, size=10000)
ax = sns.distplot(data_poisson,
                  kde=False,
                  color='green')
ax.set(xlabel='Poisson', ylabel='Frequency')
# Out:
# [Text(0, 0.5, 'Frequency'), Text(0.5, 0, 'Poisson')]

# %%
from scipy.stats import beta

data_beta = beta.rvs(1, 1, size=10000)
ax = sns.distplot(data_beta,
                  kde=False,
                  bins=100,
                  color='skyblue')
ax.set(xlabel='Beta(1,1)', ylabel='Frequency')
# Out:
# [Text(0, 0.5, 'Frequency'), Text(0.5, 0, 'Beta(1,1)')]

# %%
fig = plt.figure(figsize=(12,4))

plt.subplot(2, 2, 2)
data_beta_a10b1 = beta.rvs(10, 1, size=10000)
sns.distplot(data_beta_a10b1,
             kde=False,
             bins=50,
             color='blue')
ax.set(xlabel='Beta(10,1)', ylabel='Frequency')

plt.subplot(2, 2, 1)
data_beta_a1b10 = beta.rvs(1, 10, size=10000)
ax = sns.distplot(data_beta_a1b10,
                kde=False,
                bins=100,
                color='blue')
ax.set(xlabel='Beta(1,10)', ylabel='Frequency')

plt.subplot(2, 2, 3)
data_beta_a10b10 = beta.rvs(10, 10, size=10000)
ax = sns.distplot(data_beta_a10b10,
                  kde=False,
                  bins=100,
                  color='blue')
ax.set(xlabel='Beta(10,10)', ylabel='Frequency')
# Out:
# [Text(0, 0.5, 'Frequency'), Text(0.5, 0, 'Beta(10,10)')]

# %%
from scipy.stats import gamma

data_gamma = gamma.rvs(a=5, size=10000)
ax = sns.distplot(data_gamma,
                  kde=False,
                  bins=100,
                  color='blue')
ax.set(xlabel='Gamma', ylabel='Frequency')
# Out:
# [Text(0, 0.5, 'Frequency'), Text(0.5, 0, 'Gamma')]

# %%
from scipy.stats import lognorm

data_lognorm = lognorm.rvs(0.2, size=10000)
ax = sns.distplot(data_lognorm,kde=False,
                  bins=100,
                  color='blue')
ax.set(xlabel='Log Normal', ylabel='Frequency')
# Out:
# [Text(0, 0.5, 'Frequency'), Text(0.5, 0, 'Log Normal')]

# %%
from scipy.stats import nbinom
data_nbinom = nbinom.rvs(10, 0.5, size=10000)

ax = sns.distplot(data_nbinom,
                  kde=False,
                  color='blue')
ax.set(xlabel='Negative Binomial', ylabel='Frequency')
# Out:
# [Text(0, 0.5, 'Frequency'), Text(0.5, 0, 'Negative Binomial')]

# %%
from scipy import stats
def joint_distribution(n):
     "Measurement model, return two coupled measurements."
     m1 = np.random.normal(size=n)
     m2 = np.random.normal(scale=0.5, size=n)
     return m1+m2, m1-m2

# %%
m1, m2 = joint_distribution(2000)
xmin = m1.min()
xmax = m1.max()
ymin = m2.min()
ymax = m2.max()

X, Y = np.mgrid[xmin:xmax:100j, ymin:ymax:100j]
positions = np.vstack([X.ravel(), Y.ravel()])
values = np.vstack([m1, m2])
kernel = stats.gaussian_kde(values)
Z = np.reshape(kernel(positions).T, X.shape)

fig, ax = plt.subplots()
#ax.imshow(np.rot90(Z), cmap=plt.cm.gist_earth_r,
#          extent=[xmin, xmax, ymin, ymax])
ax.plot(m1, m2, 'k.', markersize=2)
ax.set_xlim([xmin, xmax])
ax.set_ylim([ymin, ymax])
plt.show()
